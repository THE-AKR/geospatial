# %%
import geopandas as gpd
import folium
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

pd.pandas.set_option('display.max_columns', None)
pd.pandas.set_option('display.max_rows',None)

import warnings
warnings.filterwarnings('ignore')

# %%
#shp- shapefile- geometry
#dbf- database - extra info
#prj- projection
#shx - index

# %%
building=gpd.read_file("Building Data Soondh_region_region.dbf")

# %%
building
# Out:
#      BuildingUn  SNO               Name   Plot_Size         Building_U  \
# 0           406  406        SHIVNARAYAN     1 BISWA               RESI
# 1           252  252             RAJBIR   100 YARDS               RESI
# 2           251  251       NARESH KUMAR   100 YARDS               RESI
# 3           250  250             MUKESH   200 YARDS         RESI +SHOP
# 4           158  158             GORDAN     4 BISWA               GAIR
# 5            81   81              NANAK     1 BISWA               RESI
# 6           497  497            KRISHNA   0.5 BISWA               RESI
# 7           480  480           RAGHUVIR   420 sq ft               RESI
# 8           479  479               AZIZ     2 BISWA               GAIR
# 9           474  474             MASJID        None               None
# 10          501  501              DEEPA     2 BISWA               RESI
# 11          502  502           PYARELAL     1 BISWA               RESI
# ...

# %%
building.describe(include="all")
# Out:
#         BuildingUn         SNO       Name Plot_Size Building_U   USE Caste  \
# count   668.000000  668.000000        638       623        617   639   648
# unique         NaN         NaN        419        44         20    19     4
# top            NaN         NaN  KALIYADAS   1 BISWA       RESI  RESI    SC
# freq           NaN         NaN          9       223        435   441   295
# mean    305.633234  305.633234        NaN       NaN        NaN   NaN   NaN
# std     193.247948  193.247948        NaN       NaN        NaN   NaN   NaN
# min       0.000000    0.000000        NaN       NaN        NaN   NaN   NaN
# 25%     134.750000  134.750000        NaN       NaN        NaN   NaN   NaN
# 50%     306.500000  306.500000        NaN       NaN        NaN   NaN   NaN
# 75%     474.250000  474.250000        NaN       NaN        NaN   NaN   NaN
# max     641.000000  641.000000        NaN       NaN        NaN   NaN   NaN
#
#        Remark                                           geometry
# ...

# %%
#667 unique geometry means two people lives in same building

# %%
land=gpd.read_file("Open Land_region.dbf")

# %%
land.plot()
# Out:
# <AxesSubplot:>

# %%
land
# Out:
#    OPEN_LA_ID  AREA                                           geometry
# 0       -9999   0.0  POLYGON Z ((695226.482 3127950.485 0.000, 6952...
# 1       -9999   0.0  POLYGON Z ((695546.025 3127860.943 0.000, 6955...
# 2       -9999   0.0  POLYGON Z ((695318.885 3127501.436 0.000, 6953...
# 3       -9999   0.0  POLYGON Z ((695117.851 3127538.439 0.000, 6951...
# 4       -9999   0.0  POLYGON Z ((695143.578 3127603.655 0.000, 6951...

# %%
land.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OPEN_LA_ID  5 non-null      int64
#  1   AREA        5 non-null      float64
#  2   geometry    5 non-null      geometry
# dtypes: float64(1), geometry(1), int64(1)
# memory usage: 248.0 bytes

# %%
land.geometry.area
# Out:
# 0     4349.932861
# 1    10187.152840
# 2    50016.108413
# 3     2514.249011
# 4     3345.629646
# dtype: float64

# %%
land.crs
# Out:
# <Projected CRS: EPSG:32643>
# Name: WGS 84 / UTM zone 43N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 72°E and 78°E, northern hemisphere between equator and 84°N, onshore and offshore. China. India. Kazakhstan. Kyrgyzstan. Maldives. Pakistan. Russian Federation. Tajikistan.
# - bounds: (72.0, 0.0, 78.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 43N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
land.loc[1] #how to view complete values of geometry ?
# Out:
# OPEN_LA_ID                                                -9999
# AREA                                                        0.0
# geometry      POLYGON Z ((695546.0250817148 3127860.94297901...
# Name: 1, dtype: object

# %%
land.geometry.unique()
# Out:
# <GeometryArray>
# [<POLYGON Z ((695226.482 3127950.485 0, 695259.408 3127952.384 0, 695294.246 ...>,
#  <POLYGON Z ((695546.025 3127860.943 0, 695544.195 3127865.562 0, 695532.057 ...>,
#  <POLYGON Z ((695318.885 3127501.436 0, 695316.898 3127531.33 0, 695302.055 3...>,
#  <POLYGON Z ((695117.851 3127538.439 0, 695134.912 3127541.478 0, 695144.197 ...>,
#  <POLYGON Z ((695143.578 3127603.655 0, 695162.907 3127600.556 0, 695165.174 ...>]
# Length: 5, dtype: geometry

# %%
building.Caste.unique()
# Out:
# array(['SC', 'GEN', None, 'OBC', 'BC'], dtype=object)

# %%
building.isna().sum()
# Out:
# BuildingUn      0
# SNO             0
# Name           30
# Plot_Size      45
# Building_U     51
# USE            29
# Caste          20
# Remark        668
# geometry        0
# dtype: int64

# %%
building.shape
# Out:
# (668, 9)

# %%
building.set_index("SNO")
# Out:
#      BuildingUn               Name   Plot_Size         Building_U  \
# SNO
# 406         406        SHIVNARAYAN     1 BISWA               RESI
# 252         252             RAJBIR   100 YARDS               RESI
# 251         251       NARESH KUMAR   100 YARDS               RESI
# 250         250             MUKESH   200 YARDS         RESI +SHOP
# 158         158             GORDAN     4 BISWA               GAIR
# 81           81              NANAK     1 BISWA               RESI
# 497         497            KRISHNA   0.5 BISWA               RESI
# 480         480           RAGHUVIR   420 sq ft               RESI
# 479         479               AZIZ     2 BISWA               GAIR
# 474         474             MASJID        None               None
# 501         501              DEEPA     2 BISWA               RESI
# 502         502           PYARELAL     1 BISWA               RESI
# 503         503     RAVINDRA KUMAR     1 BISWA               RESI
# ...

# %%
building[building.SNO==1]
# Out:
#      BuildingUn  SNO   Name Plot_Size Building_U   USE Caste Remark  \
# 474           1    1  IBRAN   2 BISWA       RESI  RESI   OBC   None
#
#                                               geometry
# 474  POLYGON Z ((694826.905 3127771.971 0.000, 6948...

# %%
building[building.SNO==1]
# Out:
#      BuildingUn  SNO   Name Plot_Size Building_U   USE Caste Remark  \
# 474           1    1  IBRAN   2 BISWA       RESI  RESI   OBC   None
#
#                                               geometry
# 474  POLYGON Z ((694826.905 3127771.971 0.000, 6948...

# %%
building[building.SNO==1].plot()
# Out:
# <AxesSubplot:>

# %%
building[building.SNO==2].plot()
# Out:
# <AxesSubplot:>

# %%
building[building.SNO==1].area #2biswa == 204 ???
# Out:
# 474    204.487474
# dtype: float64

# %%
building.Building_U.unique()
# Out:
# array(['RESI', 'RESI +SHOP', 'GAIR', None, 'VP', 'BETAK', 'V.P', 'SHOP',
#        'RESI, V.P', 'PLOT BON', 'OLD BLDG', 'GAIR, SHOP',
#        'RESI, GAIR, V.P', 'V.P, GAIR', 'GOD', 'RESISHOP', 'V.P OLD BLD',
#        'RESI +POST OFFICE', 'GAIR OLD BLDG', 'TUBLE V/P', 'CONSUTCRION'],
#       dtype=object)

# %%
building[building.Building_U=="RESI"]
# Out:
#      BuildingUn  SNO               Name   Plot_Size Building_U   USE Caste  \
# 0           406  406        SHIVNARAYAN     1 BISWA       RESI  RESI    SC
# 1           252  252             RAJBIR   100 YARDS       RESI  RESI    SC
# 2           251  251       NARESH KUMAR   100 YARDS       RESI  RESI    SC
# 5            81   81              NANAK     1 BISWA       RESI  RESI    SC
# 6           497  497            KRISHNA   0.5 BISWA       RESI  RESI    SC
# 7           480  480           RAGHUVIR   420 sq ft       RESI  RESI    SC
# 10          501  501              DEEPA     2 BISWA       RESI  RESI    SC
# 11          502  502           PYARELAL     1 BISWA       RESI  RESI    SC
# 12          503  503     RAVINDRA KUMAR     1 BISWA       RESI  RESI    SC
# 13          523  523             SURESH     1 BISWA       RESI  RESI    SC
# 14          521  521         SHER SINGH     2 BISWA       RESI  RESI    SC
# ...

# %%
building[building.Building_U=="RESI"].count()
# Out:
# BuildingUn    435
# SNO           435
# Name          435
# Plot_Size     435
# Building_U    435
# USE           435
# Caste         434
# Remark          0
# geometry      435
# dtype: int64

# %%
building.USE.unique()
# Out:
# array(['RESI', 'RESI /SHOP', 'GHER', 'MASZID', 'VP', 'CHAUPAL', 'SHP',
#        'SHOP', 'MANDIR', 'WATER SUPPLY', None, 'INSTITUTION',
#        'HELTH CENTER', 'AAGANWADI', 'RESI/SHOP', 'ABENDON',
#        'RESI /POST OFFICE', 'COMMUNITY CENTER', 'RESI +SHOP',
#        'CONSTRUCTION'], dtype=object)

# %%
building[building.USE=="MANDIR"]
# Out:
#      BuildingUn  SNO    Name Plot_Size Building_U     USE Caste Remark  \
# 200          56   56  MANDIR      None       None  MANDIR   OBC   None
# 387         349  349  MANDIR   5 BISWA       None  MANDIR  None   None
#
#                                               geometry
# 200  POLYGON Z ((694844.337 3127838.138 0.000, 6948...
# 387  POLYGON Z ((695183.983 3127694.297 0.000, 6951...

# %%
building.geometry.iloc[200]
# Out:
# <POLYGON Z ((694844.337 3127838.138 0, 694841.574 3127825.33 0, 694830.426 3...>

# %%
building.geometry.iloc[200].area
# Out:
# 162.63345021177568

# %%
building.geometry.iloc[349].area
# Out:
# 207.17944209813638

# %%
building.geometry.iloc[349]
# Out:
# <POLYGON Z ((695517.964 3127808.044 0, 695521.7 3127823.051 0, 695534.242 31...>

# %%
building.geometry.plot(cmap="rainbow")
# Out:
# <AxesSubplot:>

# %%
building.geometry.iloc[200].length
# Out:
# 51.50198550681988

# %%
building.geometry.iloc[80]
# Out:
# <POLYGON Z ((694838.515 3127498.627 0, 694838.515 3127493.918 0, 694825.858 ...>

# %%
building.geometry.iloc[80].length #441 sq feet in real
# Out:
# 34.73282496444881

# %%
building.geometry.iloc[80].area
# Out:
# 59.604085139945965

# %%
building.geometry.iloc[81].area #2704 sq ft in real
# Out:
# 78.7162059269379

# %%
building.geometry.iloc[81].length
# Out:
# 39.97175859566778

# %%
#indian epsg
24378
24383
24381
24380
24379
37203
4146
24347
24342
24344

# %%
building.crs= {'init': 'epsg:4326'}

# %%
building.geometry.iloc[81].length
# Out:
# 39.97175859566778

# %%
building.geometry.iloc[81].area
# Out:
# 78.7162059269379

# %%
building.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   BuildingUn  668 non-null    int64
#  1   SNO         668 non-null    int64
#  2   Name        638 non-null    object
#  3   Plot_Size   623 non-null    object
#  4   Building_U  617 non-null    object
#  5   USE         639 non-null    object
#  6   Caste       648 non-null    object
#  7   Remark      0 non-null      object
#  8   geometry    668 non-null    geometry
# dtypes: geometry(1), int64(2), object(6)
# memory usage: 47.1+ KB

# %%
building.geometry.plot(cmap="rainbow")
# Out:
# <Axes: >

# %% [markdown]
# 1 Biswa = 450 square feet (approximately)
#
# 1 Yard = 9 square feet
#
# 1 Marla = 272.25 square feet (approximately)
#
# 1 Gaj = 9 square feet

# %% [markdown]
# <h1> analysis</h1>

# %%
building.head()
# Out:
#    BuildingUn  SNO          Name  Plot_Size  Building_U         USE Caste  \
# 0         406  406   SHIVNARAYAN    1 BISWA        RESI        RESI    SC
# 1         252  252        RAJBIR  100 YARDS        RESI        RESI    SC
# 2         251  251  NARESH KUMAR  100 YARDS        RESI        RESI    SC
# 3         250  250        MUKESH  200 YARDS  RESI +SHOP  RESI /SHOP    SC
# 4         158  158        GORDAN    4 BISWA        GAIR        GHER   GEN
#
#   Remark                                           geometry
# 0   None  POLYGON Z ((695270.50669 3127733.44893 0.00000...
# 1   None  POLYGON Z ((695115.02305 3127952.13442 0.00000...
# 2   None  POLYGON Z ((695127.96078 3127965.51169 0.00000...
# 3   None  POLYGON Z ((695139.28232 3127955.15380 0.00000...
# 4   None  POLYGON Z ((694975.17353 3127794.12658 0.00000...

# %% [markdown]
# <h2> no. of plots based on caste </h2>

# %%
building.Caste.value_counts()
# Out:
# Caste
# SC     295
# OBC    179
# BC     123
# GEN     51
# Name: count, dtype: int64

# %%
Caste=building.Caste.value_counts()
Caste.plot.bar(grid=True, cmap="rainbow")
# Out:
# <Axes: xlabel='Caste'>

# %% [markdown]
# <h2> 1) SC possess large number of plots  </h2>

# %%
#lets what type of size sc and all caste have

# %%
building[building.Caste=="SC"].Plot_Size.value_counts()
# Out:
# Plot_Size
# 1 BISWA       116
# 0.5 BISWA      60
# 2 BISWA        32
# .5 BISWA       23
# 100 YARDS       8
# 40 yard         8
# 50 YARDS        6
# 3 BISWA         5
# 4 BISWA         4
# 200 YARDS       3
# 40 GAJ          2
# 80 YARDS        2
# 1.5 BISWA       2
# 70 yard         2
# 40 YARDS        2
# 159 GAJ         1
# 200 GAJ         1
# 300 YARDS       1
# 2BISWAS         1
# 600 YARDS       1
# 441 sq ft       1
# 300 GAJ         1
# 2704 sq ft      1
# 167 GAJ         1
# 50 GAJ          1
# 70 GAJ          1
# 10 BISWA        1
# 80 GAJ          1
# 3 MARLA         1
# 420 sq ft       1
# 2.5 BISWA       1
# Name: count, dtype: int64

# %% [markdown]
# # 2)mostly sc have around 1 biswa plots means 50 gaj (450 sq ft)

# %% [markdown]
# #i have to convert them into 1 scale so i can assume the approximate results

# %% [markdown]
# <h3>lets scale all plt size into sq ft </h3>

# %%
df= building.copy()     #creating a copy first

# %%
df
# Out:
#      BuildingUn  SNO               Name   Plot_Size         Building_U  \
# 0           406  406        SHIVNARAYAN     1 BISWA               RESI
# 1           252  252             RAJBIR   100 YARDS               RESI
# 2           251  251       NARESH KUMAR   100 YARDS               RESI
# 3           250  250             MUKESH   200 YARDS         RESI +SHOP
# 4           158  158             GORDAN     4 BISWA               GAIR
# 5            81   81              NANAK     1 BISWA               RESI
# 6           497  497            KRISHNA   0.5 BISWA               RESI
# 7           480  480           RAGHUVIR   420 sq ft               RESI
# 8           479  479               AZIZ     2 BISWA               GAIR
# 9           474  474             MASJID        None               None
# 10          501  501              DEEPA     2 BISWA               RESI
# 11          502  502           PYARELAL     1 BISWA               RESI
# ...

# %%
df[df.Plot_Size.str.contains("BISWA") & df["Plot_Size"].notna()] #selecting biswa first
# Out:
#      BuildingUn  SNO               Name   Plot_Size         Building_U  \
# 0           406  406        SHIVNARAYAN     1 BISWA               RESI
# 4           158  158             GORDAN     4 BISWA               GAIR
# 5            81   81              NANAK     1 BISWA               RESI
# 6           497  497            KRISHNA   0.5 BISWA               RESI
# 8           479  479               AZIZ     2 BISWA               GAIR
# 10          501  501              DEEPA     2 BISWA               RESI
# 11          502  502           PYARELAL     1 BISWA               RESI
# 12          503  503     RAVINDRA KUMAR     1 BISWA               RESI
# 13          523  523             SURESH     1 BISWA               RESI
# 14          521  521         SHER SINGH     2 BISWA               RESI
# 15          525  525        LAXMI CHAND     1 BISWA               RESI
# 16          522  522          RAM SINGH     1 BISWA               RESI
# ...

# %%
building.Plot_Size.value_counts()
# Out:
# Plot_Size
# 1 BISWA       223
# 2 BISWA        86
# 0.5 BISWA      72
# .5 BISWA       62
# 1.5 BISWA      29
# 3 BISWA        25
# 4 BISWA        22
# 5 BISWA        14
# 100 YARDS      10
# 40 yard         8
# 2.5 BISWA       8
# 50 YARDS        7
# 200 YARDS       7
# 6 BISWA         4
# 1.75 BISWA      3
# 10 BISWA        3
# 80 YARDS        3
# .4 BISWA        2
# 40 YARDS        2
# 40 GAJ          2
# 200 GAJ         2
# 4 MARLE         2
# 70 yard         2
# 300 YARDS       2
# 70 YARDS        2
# 3 MARLA         2
# 80 GAJ          2
# 4 KANAL         1
# 10 YARDS        1
# 30 FT           1
# 420 sq ft       1
# 600 YARDS       1
# 70 GAJ          1
# 1 KANAL         1
# 50 GAJ          1
# 300 GAJ         1
# 159 GAJ         1
# 2BISWAS         1
# 167 GAJ         1
# 60 GAJ          1
# 441 sq ft       1
# 2704 sq ft      1
# 20 YARDS        1
# 15 FT           1
# Name: count, dtype: int64

# %%
df[df.Plot_Size.str.contains("BISWA") & df["Plot_Size"].notna()].count() #554 values in form of biswa
# Out:
# BuildingUn    554
# SNO           554
# Name          554
# Plot_Size     554
# Building_U    548
# USE           554
# Caste         545
# Remark          0
# geometry      554
# dtype: int64

# %%
#1 biswa = 450 sq ft
x=df[df.Plot_Size.str.contains("BISWA")& df["Plot_Size"].notna()]

# %%
x=x.Plot_Size

# %%
def converter(a):
    if a.str.contains("BISWA"):
        #first we have to split the number and biswa then multiply with 450 sq ft

# %%
x.str.split(" ")
# Out:
# 0         [1, BISWA]
# 4         [4, BISWA]
# 5         [1, BISWA]
# 6       [0.5, BISWA]
# 8         [2, BISWA]
# 10        [2, BISWA]
# 11        [1, BISWA]
# 12        [1, BISWA]
# 13        [1, BISWA]
# 14        [2, BISWA]
# 15        [1, BISWA]
# 16        [1, BISWA]
# 17        [1, BISWA]
# 18        [1, BISWA]
# 19        [2, BISWA]
# 20        [2, BISWA]
# 21        [4, BISWA]
# 22      [2.5, BISWA]
# 25        [1, BISWA]
# 26        [1, BISWA]
# 28        [1, BISWA]
# 29      [0.5, BISWA]
# 30        [1, BISWA]
# 31        [1, BISWA]
# 34       [10, BISWA]
# 35        [2, BISWA]
# 36        [1, BISWA]
# 37        [2, BISWA]
# 38        [1, BISWA]
# 39      [0.5, BISWA]
# 40        [1, BISWA]
# 41        [1, BISWA]
# 42      [0.5, BISWA]
# 44      [0.5, BISWA]
# 45      [0.5, BISWA]
# 46      [0.5, BISWA]
# 48      [0.5, BISWA]
# 49      [0.5, BISWA]
# 50        [1, BISWA]
# 51        [1, BISWA]
# 53      [0.5, BISWA]
# 54        [1, BISWA]
# 55        [1, BISWA]
# ...

# %%
test=x.str.split(" ",expand=True)

# %%
test
# Out:
#            0      1
# 0          1  BISWA
# 4          4  BISWA
# 5          1  BISWA
# 6        0.5  BISWA
# 8          2  BISWA
# 10         2  BISWA
# 11         1  BISWA
# 12         1  BISWA
# 13         1  BISWA
# 14         2  BISWA
# 15         1  BISWA
# 16         1  BISWA
# 17         1  BISWA
# 18         1  BISWA
# 19         2  BISWA
# 20         2  BISWA
# 21         4  BISWA
# 22       2.5  BISWA
# 25         1  BISWA
# 26         1  BISWA
# 28         1  BISWA
# 29       0.5  BISWA
# 30         1  BISWA
# 31         1  BISWA
# 34        10  BISWA
# 35         2  BISWA
# 36         1  BISWA
# 37         2  BISWA
# 38         1  BISWA
# 39       0.5  BISWA
# 40         1  BISWA
# 41         1  BISWA
# 42       0.5  BISWA
# 44       0.5  BISWA
# 45       0.5  BISWA
# 46       0.5  BISWA
# 48       0.5  BISWA
# 49       0.5  BISWA
# 50         1  BISWA
# 51         1  BISWA
# 53       0.5  BISWA
# 54         1  BISWA
# 55         1  BISWA
# 56         1  BISWA
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 554 entries, 0 to 667
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       554 non-null    object
#  1   1       553 non-null    object
# dtypes: object(2)
# memory usage: 29.1+ KB

# %%
test.rename(columns={0:"First",1:"values"},inplace=True)

# %%
test
# Out:
#        First values
# 0          1  BISWA
# 4          4  BISWA
# 5          1  BISWA
# 6        0.5  BISWA
# 8          2  BISWA
# 10         2  BISWA
# 11         1  BISWA
# 12         1  BISWA
# 13         1  BISWA
# 14         2  BISWA
# 15         1  BISWA
# 16         1  BISWA
# 17         1  BISWA
# 18         1  BISWA
# 19         2  BISWA
# 20         2  BISWA
# 21         4  BISWA
# 22       2.5  BISWA
# 25         1  BISWA
# 26         1  BISWA
# 28         1  BISWA
# 29       0.5  BISWA
# 30         1  BISWA
# 31         1  BISWA
# 34        10  BISWA
# 35         2  BISWA
# 36         1  BISWA
# 37         2  BISWA
# 38         1  BISWA
# 39       0.5  BISWA
# 40         1  BISWA
# 41         1  BISWA
# 42       0.5  BISWA
# 44       0.5  BISWA
# 45       0.5  BISWA
# 46       0.5  BISWA
# 48       0.5  BISWA
# 49       0.5  BISWA
# 50         1  BISWA
# 51         1  BISWA
# 53       0.5  BISWA
# 54         1  BISWA
# 55         1  BISWA
# 56         1  BISWA
# ...

# %%
test_f= test.First

# %%
test_f
# Out:
# 0            1
# 4            4
# 5            1
# 6          0.5
# 8            2
# 10           2
# 11           1
# 12           1
# 13           1
# 14           2
# 15           1
# 16           1
# 17           1
# 18           1
# 19           2
# 20           2
# 21           4
# 22         2.5
# 25           1
# 26           1
# 28           1
# 29         0.5
# 30           1
# 31           1
# 34          10
# 35           2
# 36           1
# 37           2
# 38           1
# 39         0.5
# 40           1
# 41           1
# 42         0.5
# 44         0.5
# 45         0.5
# 46         0.5
# 48         0.5
# 49         0.5
# 50           1
# 51           1
# 53         0.5
# 54           1
# 55           1
# 56           1
# 57           1
# 58         0.5
# 59         0.5
# 60         0.5
# 61         0.5
# 62         0.5
# 63           3
# 64           1
# 65           3
# 66           4
# 70         0.5
# 71           1
# 74         0.5
# 75         0.5
# ...

# %%
int(test_f)*450
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 int(test_f)*450
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>

# %%
from ast import literal_eval
test_f= literal_eval(test_f)
test_f.type
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[119], line 2
#       1 from ast import literal_eval
# ----> 2 test_f= literal_eval(test_f)
#       3 test_f.type
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ast.py:112, in literal_eval(node_or_string)
#     110                 return left - right
#     111     return _convert_signed_num(node)
# --> 112 return _convert(node_or_string)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ast.py:111, in literal_eval.<locals>._convert(node)
#     109         else:
#     110             return left - right
# --> 111 return _convert_signed_num(node)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\ast.py:85, in literal_eval.<locals>._convert_signed_num(node)
#      83     else:
#      84         return - operand
# ---> 85 return _convert_num(node)
#
# ...

# %%
#index at 267

# %%
test.iloc[267]
# Out:
# First         1
# values    BISWA
# Name: 321, dtype: object

# %%
building[building["Name"]=="NANDKISHORE"]
# Out:
#      BuildingUn  SNO         Name  Plot_Size Building_U   USE Caste Remark  \
# 261         311  311  NANDKISHORE    2 BISWA       RESI  RESI    BC   None
# 271         396  396  NANDKISHORE  0.5 BISWA        V.P    VP    SC   None
#
#                                               geometry
# 261  POLYGON Z ((695137.724 3127810.203 0.000, 6951...
# 271  POLYGON Z ((695201.093 3127800.425 0.000, 6951...

# %%
building[building["Name"]=="NANDKISHORE"].plot()
# Out:
# <Axes: >

# %%
building[building["Name"].str.contains("KHAN") & building["Name"].notna()]
# Out:
#      BuildingUn  SNO       Name Plot_Size Building_U   USE Caste Remark  \
# 545         478  478  SAMADKHAN   1 BISWA       RESI  RESI   GEN   None
#
#                                               geometry
# 545  POLYGON Z ((694982.702 3127511.244 0.000, 6949...
